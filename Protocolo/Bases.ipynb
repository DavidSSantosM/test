# %% [markdown]
# ## Lectura base

# %% [markdown]
# ### Librerías

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Carga archivo

# %%
df = pd.read_csv(r"C:\Users\DavidSebastianSantos\Downloads\data_cargo.csv", sep=";")
df

# %% [markdown]
# ### Consultas

# %%
fuentes = df[['fuente']]
fuentes

# %%
df["fuente"].count()

# %%
fuentes
