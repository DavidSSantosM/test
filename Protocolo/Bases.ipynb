# %% [markdown]
# ## Lectura base

# %% [markdown]
# ### Librerías

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Carga archivo

# %%
df = pd.read_excel(r"C:\Users\DavidSebastianSantos\Downloads\data_cargo.xlsx")
df
# Out:
#     fuente                                id  \
# 0       CT  121353B1447F3DBF61373E686DCF3405
# 1       CT  DCAD67497EF99F0561373E686DCF3405
# 2       CT  921FE1BAFAD2ED7C61373E686DCF3405
# 3       CT  2A0F5B5C9D71F0D761373E686DCF3405
# 4       CT  75E581D691581B9461373E686DCF3405
# ..     ...                               ...
# 295     CT  ED3D1FB42510128B61373E686DCF3405
# 296     CT  A8247246D4C1788461373E686DCF3405
# 297     CT  CC0A5E9E2300910561373E686DCF3405
# 298     CT  274D3A61F9B2EF4561373E686DCF3405
# 299     CT  9CFB9B17A6076D9C61373E686DCF3405
#
#                                              job_title  \
# 0        asesor comercial call center portugues fluido
# 1                             soldador con experiencia
# 2    auxiliar logistico con manejo de estibador ele...
# 3                                            motorista
# 4                           psicologoa con experiencia
# ..                                                 ...
# ...

# %% [markdown]
# ### Consultas

# %%
fuentes = df[['fuente']].drop_duplicates()
fuentes
# Out:
#   fuente
# 0     CT

# %%
df["fuente"].count()
# Out:
# 300
