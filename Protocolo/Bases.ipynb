# %% [markdown]
# ### Lectura base

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\DavidSebastianSantos\Downloads\SO_vs_PP.xlsx")
df
# Out:
#     Unnamed: 0  Unnamed: 1 SELL OUT Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN     2022        NaN        NaN       2023
# 1          NaN         NaN     AMAZ       MELI         PP       AMAZ
# 2       CERAVE       Enero  6058069    3816973    9875042   14662176
# 3          NaN     Febrero  5350628    4305197    9655825   14349568
# 4          NaN       Marzo  6086197    5350058   11436255   14487391
# ..         ...         ...      ...        ...        ...        ...
# 201        NaN      Agosto      NaN        NaN          0     991213
# 202        NaN  Septiembre      NaN        NaN          0     755076
# 203        NaN     Octubre      NaN        NaN          0    1347228
# 204        NaN   Noviembre      NaN        NaN          0    1965364
# 205        NaN   Diciembre      NaN        NaN          0    1025560
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...
